# %%
# !pip install PyCryptodome
# Out:
# Collecting PyCryptodome
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 36.2 MB/s eta 0:00:00
# Installing collected packages: PyCryptodome
# Successfully installed PyCryptodome-3.23.0

# %%
from Crypto.Cipher import DES
from Crypto.Random import get_random_bytes

# %%
def pad_text(text):
    # Ensure the plaintext length is a multiple of 8 bytes (DES block size)
    #generate and return the padded_text
    padded_length= 8-len(text)%8
    print(padded_length)
    if padded_length%8==0:
        return padded_text
    else:
        padded_text= text+ bytes([padded_length]*padded_length)
        return padded_text

# %%
def des_encrypt(plaintext, key):
    #encrypt DES(Mode:ECB) and return the ciphertext
    cipher = DES.new(key, DES.MODE_ECB)
    ciphertext = cipher.encrypt(plaintext)
    return ciphertext

# %%
plaintext = b"This is a secret text"
key = get_random_bytes(8)  # Generate a random 64-bit (8-byte) key

print("Original plaintext:", plaintext.decode('utf-8'))
print("Original key (in bytes):", key)

plaintext = pad_text(plaintext)

ciphertext = des_encrypt(plaintext, key)
print("Encrypted ciphertext (in bytes):", ciphertext)
# Out:
# Original plaintext: This is a secret text
# Original key (in bytes): b'\xd9\xdcs\xb6\xa5\x963\xf0'
# Encrypted ciphertext (in bytes): b'\xc5.\xa8v\xb7~8\x9fO\x10\xeaZ?c\x80\xa2.YPOgXz\x99'

# %%
def unpad_text(padded_text):
    # Remove the padding bytes to get the original plaintext
    # Done for you
    padding_length = padded_text[-1]
    if padding_length > 0 and padding_length <= 8:
        return padded_text[:-padding_length]
    else:
        return padded_text

# %%
def des_decrypt(ciphertext, key):
    cipher = DES.new(key, DES.MODE_ECB)
    plaintext = cipher.decrypt(ciphertext)

    return plaintext

r_plaintext=des_decrypt(ciphertext,key)

r_plaintext=unpad_text(r_plaintext)
print(r_plaintext)
# Out:
# b'This is a secret text'

# %%
# Replace these with your ciphertext and key
ciphertext = b"'i\x8b\xb3\xfd>\x1b%\xdd;\xd18\xf8go\xde6\xa3GH\x03\xd0\xc2\x97"
key = b'\xf1\xb4\xd6\x80\\_\x06C'

decrypted_text = des_decrypt(ciphertext, key)
original_text = unpad_text(decrypted_text)

print("Decrypted text:", original_text.decode('utf-8'))
# Out:
# Decrypted text: This is a secret text

# %%
#Implement Double DES and check if your ciphertext matches the provided output.
plaintext = b"I am Batman"
KeyA = b'\x01\xadWR\xeb\x1a\xa2\x86'
KeyB = b'\xf7\xcf\xd6r\xd9\xa1\x141'
Given_Output = b'\xd2Em\x06-1\xf7$\x0c\xaaI\xf0\xc3\x00\xbd}@\xae\x0e\x8c0\xf4\xb6\xac'

padded_text1=pad_text(plaintext)
ciphertext1=des_encrypt(padded_text1,KeyA)
padded_text2=pad_text(ciphertext1)
ciphertext2=des_encrypt(padded_text2,KeyB)

print(len(ciphertext1))
print(ciphertext1)

print(len(ciphertext2))

if ciphertext2==Given_Output:
    print(True)
# Out:
# 5
# 8
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-78-2705434294.py in <cell line: 0>()
#       7 padded_text1=pad_text(plaintext)
#       8 ciphertext1=des_encrypt(padded_text1,KeyA)
# ----> 9 padded_text2=pad_text(ciphertext1)
#      10 ciphertext2=des_encrypt(padded_text2,KeyB)
#      11
#
# /tmp/ipython-input-77-733911620.py in pad_text(text)
#       5     print(padded_length)
#       6     if padded_length%8==0:
# ----> 7         return padded_text
#       8     else:
#       9         padded_text= text+ bytes([padded_length]*padded_length)
#
# UnboundLocalError: cannot access local variable 'padded_text' where it is not associated with a value

# %%
#Pattern Repetition in DES ECB Mode Ciphertext
plaintext = b"ABCDEFGHABCDEFGHABCDEFGH"
key = get_random_bytes(8)  # Generate a random 64-bit (8-byte) key

padtext = pad_text(plaintext)
c1 = des_encrypt(padtext,key)
print(c1)
# Out:
# b'\x06\xceZ^\x7f\x95?\x9a\x06\xceZ^\x7f\x95?\x9a\x06\xceZ^\x7f\x95?\x9a\x8bg\xbd\t!\xfe\xd2F'
