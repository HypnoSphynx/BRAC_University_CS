# %% [markdown]
# # RSA

# %%
m = int("Secret".encode("utf-8").hex(),16)
print(m)
# Out:
# 91694925243764

# %%
#generate large prime(128 bits) p and q
import random
from sympy import isprime

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        num |= (1 << (bits - 1)) | 1
        if isprime(num):
            return num

# Generate two 128-bit prime numbers
p = generate_prime(128)
q = generate_prime(128)

print(f"p: {p}")
print(f"q: {q}")
# Out:
# p: 221397714191620539488902923812367059023
# q: 295548129230502712488353130931155396101

# %%
#Calculate n = pq

n=p*q
print(n)
# Out:
# 65433680245242971583805564328948835684608959784063270475218465836966011069323

# %%
#Calculate phi(n)=(p-1)(q-1)
phi_n=(p-1)*(q-1)
print(phi_n)
# Out:
# 65433680245242971583805564328948835684092013940641147223241209782222488614200

# %%
#Perform encryption here and generate ciphertext [c = m^e (mod n)] and private key [d*e ≡ 1 (mod(phi(n)))]
e = 11
d= pow(e,-1,phi_n)
print(d)

c=pow(m,e,n)
print(c)
# Out:
# 11897032771862358469782829877990697397107638898298390404225674505858634293491
# 55881289298748729908683953239943820158357879439834710774957800796492865794670

# %%
#perform decryption here [m = c^d (mod n)]

m= pow(c,d,n)
print(m)
# Out:
# 91694925243764

# %%
m = 91694925243764
print(bytes.fromhex(hex(m)[2:]).decode('utf-8') )
# Out:
# Secret
